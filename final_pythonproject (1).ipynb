# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns

# %% [markdown]
# Import Data Set

# %%
from google.colab import files
import io

uploaded = files.upload()
df_sales = pd.read_csv("zepto_sales.csv")
# Out:
#      <input type="file" id="files-361f46ff-f5fd-4fd8-8069-a5cf18ed3197" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-361f46ff-f5fd-4fd8-8069-a5cf18ed3197">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
import io

uploaded = files.upload()
df_products = pd.read_csv("zepto_products.csv")
# Out:
#      <input type="file" id="files-dbc2c33b-0cbb-4929-9b60-5bbabc93d210" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dbc2c33b-0cbb-4929-9b60-5bbabc93d210">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # Displaying Basic Information of Products Dataset

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220220 entries, 0 to 220219
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   order_id            220220 non-null  int64
#  1   order_date          220220 non-null  object
#  2   product_id          220220 non-null  int64
#  3   quantity            220220 non-null  int64
#  4   city                219118 non-null  object
#  5   delivery_status     219118 non-null  object
#  6   customer_id         220220 non-null  int64
#  7   delivery_time_mins  215817 non-null  float64
#  8   total_amount        220220 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 15.1+ MB

# %%
df_products.describe()
# Out:
#        product_id  base_price
# count   38.000000   38.000000
# mean   119.500000  211.414474
# std     11.113055  139.411328
# min    101.000000   23.250000
# 25%    110.250000  105.307500
# 50%    119.500000  188.005000
# 75%    128.750000  290.127500
# max    138.000000  531.370000

# %%
df_products.head()
# Out:
#    product_id product_name             category  base_price
# 0         101        Apple  Fruits & Vegetables      103.13
# 1         102       Banana  Fruits & Vegetables       23.25
# 2         103        Onion  Fruits & Vegetables       55.75
# 3         104       Potato  Fruits & Vegetables       49.02
# 4         105       Tomato  Fruits & Vegetables      115.74

# %%
df_products.tail()
# Out:
#     product_id   product_name       category  base_price
# 33         134       Handwash  Personal Care      390.59
# 34         135     Toothpaste  Personal Care      182.49
# 35         136       Soap Bar  Personal Care      243.21
# 36         137      Face Wash  Personal Care      340.29
# 37         138  Sanitary Pads  Personal Care      266.48

# %%
df_products.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'base_price'], dtype='object')

# %%
df_products.isnull()
# Out:
#     product_id  product_name  category  base_price
# 0        False         False     False       False
# 1        False         False     False       False
# 2        False         False     False       False
# 3        False         False     False       False
# 4        False         False     False       False
# 5        False         False     False       False
# 6        False         False     False       False
# 7        False         False     False       False
# 8        False         False     False       False
# 9        False         False     False       False
# 10       False         False     False       False
# 11       False         False     False       False
# 12       False         False     False       False
# 13       False         False     False       False
# 14       False         False     False       False
# 15       False         False     False       False
# 16       False         False     False       False
# ...

# %% [markdown]
# # Displaying Basic information of Sales Dataset

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220220 entries, 0 to 220219
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   order_id            220220 non-null  int64
#  1   order_date          220220 non-null  object
#  2   product_id          220220 non-null  int64
#  3   quantity            220220 non-null  int64
#  4   city                219118 non-null  object
#  5   delivery_status     219118 non-null  object
#  6   customer_id         220220 non-null  int64
#  7   delivery_time_mins  215817 non-null  float64
#  8   total_amount        220220 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 15.1+ MB

# %%
df_sales.describe()
# Out:
#             order_id     product_id       quantity    customer_id  \
# count  220220.000000  220220.000000  220220.000000  220220.000000
# mean   152325.652429     119.214218       1.548633   60016.100023
# std     30172.200347      12.097782       1.003054    5781.447441
# min    100001.000000     101.000000       1.000000   50000.000000
# 25%    126144.000000     109.000000       1.000000   55019.000000
# 50%    152444.500000     118.000000       1.000000   60019.000000
# 75%    178447.250000     134.000000       2.000000   65020.000000
# max    204476.000000     138.000000       5.000000   69999.000000
#
#        delivery_time_mins   total_amount
# count       215817.000000  220220.000000
# mean            26.006246     302.336515
# std             10.670646     324.031767
# min              8.000000      23.250000
# 25%             17.000000      82.460000
# 50%             26.000000     226.870000
# 75%             35.000000     390.590000
# ...

# %%
df_sales.head()
# Out:
#    order_id           order_date  product_id  quantity       city  \
# 0    151992  2024-02-08 00:38:00         135         1  Bangalore
# 1    109440  2024-05-31 15:49:00         102         1     Mumbai
# 2    126862  2024-01-17 23:41:00         110         1     Mumbai
# 3    167258  2024-11-12 09:42:00         121         3  Hyderabad
# 4    159614  2024-01-02 17:50:00         112         4  Bangalore
#
#   delivery_status  customer_id  delivery_time_mins  total_amount
# 0       Delivered        66921                28.0        182.49
# 1       Delivered        66646                38.0         23.25
# 2       Delivered        69586                12.0         60.43
# 3       Delivered        66719                12.0        996.12
# 4       Delivered        50094                38.0        907.48

# %%
df_sales.tail()
# Out:
#         order_id           order_date  product_id  quantity       city  \
# 220215    204348  2024-04-08 00:51:00         112         2     Mumbai
# 220216    139692  2024-04-14 13:19:00         135         1  Bangalore
# 220217    155920  2024-11-22 13:49:00         110         1  Bangalore
# 220218    100568  2024-07-13 22:50:00         129         1  Bangalore
# 220219    195258  2024-07-30 11:27:00         112         1      Delhi
#
#        delivery_status  customer_id  delivery_time_mins  total_amount
# 220215       Delivered        53512                18.0        453.74
# 220216       Delivered        60871                13.0        182.49
# 220217       Delivered        66690                19.0         60.43
# 220218       Delivered        61300                14.0        531.37
# 220219       Delivered        63759                15.0        226.87

# %%
df_sales.columns
# Out:
# Index(['order_id', 'order_date', 'product_id', 'quantity', 'city',
#        'delivery_status', 'customer_id', 'delivery_time_mins', 'total_amount'],
#       dtype='object')

# %%
df_sales.isnull()
# Out:
#         order_id  order_date  product_id  quantity   city  delivery_status  \
# 0          False       False       False     False  False            False
# 1          False       False       False     False  False            False
# 2          False       False       False     False  False            False
# 3          False       False       False     False  False            False
# 4          False       False       False     False  False            False
# ...          ...         ...         ...       ...    ...              ...
# 220215     False       False       False     False  False            False
# 220216     False       False       False     False  False            False
# 220217     False       False       False     False  False            False
# 220218     False       False       False     False  False            False
# 220219     False       False       False     False  False            False
#
#         customer_id  delivery_time_mins  total_amount
# ...

# %% [markdown]
# # Data Cleaning - Handling Duplicates and missing values

# %%
df_sales.isnull().sum()
# Out:
# order_id                 0
# order_date               0
# product_id               0
# quantity                 0
# city                  1102
# delivery_status       1102
# customer_id              0
# delivery_time_mins    4403
# total_amount             0
# dtype: int64

# %%
df_products.isnull().sum()
# Out:
# product_id      0
# product_name    0
# category        0
# base_price      0
# dtype: int64

# %%
# Handle null values in 'city' and 'delivery_status' by dropping rows
# Q.For the city and delivery_status columns, remove the records (rows) tha contain NaN values.
df_sales.dropna(subset=['city','delivery_status'],inplace = True)

# %%
df_sales[["city","delivery_status"]].isnull().sum()
# Out:
# city               0
# delivery_status    0
# dtype: int64

# %%
df_sales.isnull().sum()
# Out:
# order_id                 0
# order_date               0
# product_id               0
# quantity                 0
# city                     0
# delivery_status          0
# customer_id              0
# delivery_time_mins    4346
# total_amount             0
# dtype: int64

# %%
# Handle null values in 'delivery_time_mins' by filling with the mean
# Q.For the delivery_time_mins column, fill missing values with the mean of the column.

df_sales["delivery_time_mins"]=df_sales["delivery_time_mins"].fillna(df_sales["delivery_time_mins"].mean())

# %%
df_sales.isnull().sum()
# Out:
# order_id              0
# order_date            0
# product_id            0
# quantity              0
# city                  0
# delivery_status       0
# customer_id           0
# delivery_time_mins    0
# total_amount          0
# dtype: int64

# %%
# Check for duplicate records

df_sales.duplicated().sum()
# Out:
# np.int64(216)

# %%
# Remove duplicate records

df_sales.drop_duplicates(inplace=True)

# %%
# Convert 'order_date' to datetime objects

df_sales["order_date"] = pd.to_datetime(df_sales["order_date"])

# %%
df_sales["order_date"]
# Out:
# 0        2024-02-08 00:38:00
# 1        2024-05-31 15:49:00
# 2        2024-01-17 23:41:00
# 3        2024-11-12 09:42:00
# 4        2024-01-02 17:50:00
#                  ...
# 220215   2024-04-08 00:51:00
# 220216   2024-04-14 13:19:00
# 220217   2024-11-22 13:49:00
# 220218   2024-07-13 22:50:00
# 220219   2024-07-30 11:27:00
# Name: order_date, Length: 217806, dtype: datetime64[ns]

# %% [markdown]
# # Data Analysis - Aggregations and Grouping

# %%
# min amount
min_amount = df_sales["total_amount"].min()
print(min_amount)
# Out:
# 23.25

# %%
# max amount
max_amount = df_sales["total_amount"].max()
print(max_amount)
# Out:
# 2656.85

# %%
# avg amount
avg_amount = df_sales["total_amount"].mean()
print(avg_amount)
# Out:
# 302.3239065039531

# %%
# Top 5 products by total sales amount

top_5products = df_sales.groupby("product_id")["total_amount"].sum().sort_values(ascending = False).head(5)
print(top_5products)
# Out:
# product_id
# 134    11658720.91
# 112     7908234.46
# 135     6171994.29
# 129     4796676.99
# 131     4716913.11
# Name: total_amount, dtype: float64

# %%
df_sales.columns
# Out:
# Index(['order_id', 'order_date', 'product_id', 'quantity', 'city',
#        'delivery_status', 'customer_id', 'delivery_time_mins', 'total_amount'],
#       dtype='object')

# %%
# Merge With Product Details to get Product Names.

top_products_name = top_5products.reset_index().merge(df_products,on='product_id')
print(top_products_name)
# Out:
#    product_id  total_amount   product_name              category  base_price
# 0         134   11658720.91       Handwash         Personal Care      390.59
# 1         112    7908234.46    Paneer 200g          Dairy & Eggs      226.87
# 2         135    6171994.29     Toothpaste         Personal Care      182.49
# 3         129    4796676.99  Detergent 1kg  Household Essentials      531.37
# 4         131    4716913.11   Toilet Paper  Household Essentials      513.21

# %%
# Total sales By City

total_sales = df_sales.groupby("city")["total_amount"].sum()
print(total_sales)
# Out:
# city
# Ahmedabad     1362556.30
# Bangalore    16385777.49
# Chennai       2563667.49
# Delhi         9937151.01
# Hyderabad     5305224.53
# Kolkata       2671042.99
# Mumbai       23063075.50
# Pune          4559465.47
# Name: total_amount, dtype: float64

# %%
# Average Delivery Time by city
average_delivery_time = df_sales.groupby('city')['delivery_time_mins'].mean()
print(average_delivery_time)
# Out:
# city
# Ahmedabad    26.170095
# Bangalore    26.015561
# Chennai      26.059007
# Delhi        26.037475
# Hyderabad    25.914055
# Kolkata      26.089218
# Mumbai       25.979052
# Pune         26.040857
# Name: delivery_time_mins, dtype: float64

# %%
# Sales Trend over Time (monthly sales)

#creating month column
df_sales["month"] = df_sales['order_date'].dt.to_period('M')

#Group by
monthly_sales_trends = df_sales.groupby('month')['total_amount'].sum()
print(monthly_sales_trends)
# Out:
# month
# 2024-01    5593297.49
# 2024-02    5286182.10
# 2024-03    5569350.76
# 2024-04    5375568.99
# 2024-05    5574801.37
# 2024-06    5380702.74
# 2024-07    5523114.55
# 2024-08    5468629.63
# 2024-09    5386353.65
# 2024-10    5547622.90
# 2024-11    5451878.37
# 2024-12    5690458.23
# Freq: M, Name: total_amount, dtype: float64

# %%
df_products.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'base_price'], dtype='object')

# %%
# sales By Product category

sales_by_category = df_sales.merge(df_products, on="product_id")
sales_by_category = sales_by_category.groupby("category")["total_amount"].sum().sort_values(ascending=False)
print(sales_by_category)
# Out:
# category
# Personal Care           23399215.51
# Dairy & Eggs            12344371.12
# Household Essentials    11975638.84
# Munchies                 8083367.83
# Beverages                6598799.13
# Fruits & Vegetables      3446568.35
# Name: total_amount, dtype: float64

# %% [markdown]
# # Data Visualization with Matplotlib

# %%
sns.set_style('whitegrid')

plt.rcParams['figure.figsize'] = (10,6)
plt.show()

# %% [markdown]
# # Top 5 Products by Sales Amount.

# %%
# Plot 1: Top 5 Products by Sales Amount.

plt.figure(figsize=(12,7))
sns.barplot(x = 'product_name',y = 'total_amount',hue='product_name',data = top_products_name,palette='viridis')
plt.title('Top 5 Product Names')
plt.xlabel('Product Name')
plt.ylabel('Total Sales')
plt.xticks(rotation=45,ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Total Sales by City

# %%
plt.figure(figsize=(12, 7))
sns.barplot(x = total_sales.index, y = total_sales.values,hue=total_sales.index, palette="magma")
plt.title("Total Sales by City")
plt.xlabel("City")
plt.ylabel("Total Sales Amount")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Monthly Sales Trend

# %%
plt.figure(figsize=(14, 7))
monthly_sales_trends.plot(kind="line", marker="o", color="#3498DB")
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Total Sales Amount")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Sales by Product Category (Pie Chart)

# %%
plt.figure(figsize = (10,10))
plt.pie(sales_by_category,labels =sales_by_category.index,
autopct="%1.1f%%", startangle = 140,colors = sns.color_palette('pastel'))
plt.title("Total Sales By Product Category")
plt.axis("equal")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Distribution of Delivery Times

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df_sales["delivery_time_mins"], bins=30, kde=True,
color="red")
plt.title("Distribution of Delivery Times")
plt.xlabel("Delivery Time (minutes)")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()
